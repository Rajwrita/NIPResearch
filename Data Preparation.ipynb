# %%
import pandas as pd
import csv
import os,json
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import random

#os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
os.listdir("/content/gdrive/My Drive/NPPI")
path="/content/gdrive/My Drive/NPPI"

# %%
## NIP2BACKUP FEATURE GEN FILES

# %%
DS3A=[]
DS3Aneg=[]
with open(path+"/traindata/ITRi-19/SetA.json","r") as f:
  EEX4=json.load(f)
for x in EEX4:
  if (x[2] == 1):
    DS3A.append(x)
  else:
    DS3Aneg.append(x)

# %%
DS3Aneg=random.sample(DS3Aneg, 3355)
DS3A.extend(DS3Aneg)
print(len(DS3A))
# Out:
# 6710

# %%
with open(path+"/DS/DS3A.json","w") as f:
  json.dump(DS3A,f)

# %%
DS3B=[]
DS3Bneg=[]
with open(path+"/traindata/ITRi-19/SetB.json","r") as f:
  EEX4=json.load(f)
for x in EEX4:
  if (x[2] == 1):
    DS3B.append(x)
  else:
    DS3Bneg.append(x)
DS3Bneg=random.sample(DS3Bneg, 3355)
DS3B.extend(DS3Bneg)
print(len(DS3B))
with open(path+"/DS/DS3B.json","w") as f:
  json.dump(DS3B,f)
# Out:
# 6710

# %%
DS2A=[]
DS2Aneg=[]
with open(path+"/traindata/ITRi-9/SetA.json","r") as f:
  EEX4=json.load(f)
for x in EEX4:
  if (x[2] == 1):
    DS2A.append(x)
  else:
    DS2Aneg.append(x)
DS2Aneg=random.sample(DS2Aneg, 3355)
DS2A.extend(DS2Aneg)
print(len(DS2A))
with open(path+"/DS/DS2A.json","w") as f:
  json.dump(DS2A,f)
# Out:
# 6710

# %%
DS2B=[]
DS2Bneg=[]
with open(path+"/traindata/ITRi-9/SetB.json","r") as f:
  EEX4=json.load(f)
for x in EEX4:
  if (x[2] == 1):
    DS2B.append(x)
  else:
    DS2Bneg.append(x)
DS2Bneg=random.sample(DS2Bneg, 3355)
DS2B.extend(DS2Bneg)
print(len(DS2B))
with open(path+"/DS/DS2B.json","w") as f:
  json.dump(DS2B,f)
# Out:
# 6710

# %%
DS1A=[]
DS1Aneg=[]
with open(path+"/traindata/ITRi-2/SetA.json","r") as f:
  EEX4=json.load(f)
for x in EEX4:
  if (x[2] == 1):
    DS1A.append(x)
  else:
    DS1Aneg.append(x)
DS1Aneg=random.sample(DS1Aneg, 3355)
DS1A.extend(DS1Aneg)
print(len(DS1A))
with open(path+"/DS/DS1A.json","w") as f:
  json.dump(DS1A,f)
###########
DS1B=[]
DS1Bneg=[]
with open(path+"/traindata/ITRi-2/SetB.json","r") as f:
  EEX4=json.load(f)
for x in EEX4:
  if (x[2] == 1):
    DS1B.append(x)
  else:
    DS1Bneg.append(x)
DS1Bneg=random.sample(DS1Bneg, 3355)
DS1B.extend(DS1Bneg)
print(len(DS1B))
with open(path+"/DS/DS1B.json","w") as f:
  json.dump(DS1B,f)
# Out:
# 6710
# 6710

# %%
##NIP2 DATA FILES

# %%
DS1A=[]
DS1Aneg=[]
with open(path+"/DATAfrom100itr/ITR-1/SetA.json","r") as f:
  EEX4=json.load(f)
for x in EEX4:
  if (x[2] == 1):
    DS1A.append(x)
  else:
    DS1Aneg.append(x)
DS1Aneg=random.sample(DS1Aneg, 3355)
DS1A.extend(DS1Aneg)
print(len(DS1A))
with open(path+"/DS/DS100/DS1A.json","w") as f:
  json.dump(DS1A,f)
###########
DS1B=[]
DS1Bneg=[]
with open(path+"/DATAfrom100itr/ITR-1/SetB.json","r") as f:
  EEX4=json.load(f)
for x in EEX4:
  if (x[2] == 1):
    DS1B.append(x)
  else:
    DS1Bneg.append(x)
DS1Bneg=random.sample(DS1Bneg, 3355)
DS1B.extend(DS1Bneg)
print(len(DS1B))
with open(path+"/DS/DS100/DS1B.json","w") as f:
  json.dump(DS1B,f)
# Out:
# 6710
# 6710

# %%
DS2A=[]
DS2Aneg=[]
with open(path+"/DATAfrom100itr/ITR-50/SetA.json","r") as f:
  EEX4=json.load(f)
for x in EEX4:
  if (x[2] == 1):
    DS2A.append(x)
  else:
    DS2Aneg.append(x)
DS2Aneg=random.sample(DS2Aneg, 3355)
DS2A.extend(DS2Aneg)
print(len(DS2A))
with open(path+"/DS/DS100/DS2A.json","w") as f:
  json.dump(DS2A,f)
###########
DS2B=[]
DS2Bneg=[]
with open(path+"/DATAfrom100itr/ITR-100/SetB.json","r") as f:
  EEX4=json.load(f)
for x in EEX4:
  if (x[2] == 1):
    DS2B.append(x)
  else:
    DS2Bneg.append(x)
DS2Bneg=random.sample(DS2Bneg, 3355)
DS2B.extend(DS2Bneg)
print(len(DS2B))
with open(path+"/DS/DS100/DS2B.json","w") as f:
  json.dump(DS2B,f)
# Out:
# 6710
# 6710

# %%
DS3A=[]
DS3Aneg=[]
with open(path+"/DATAfrom100itr/ITR-100/SetA.json","r") as f:
  EEX4=json.load(f)
for x in EEX4:
  if (x[2] == 1):
    DS3A.append(x)
  else:
    DS3Aneg.append(x)
DS3Aneg=random.sample(DS3Aneg, 3355)
DS3A.extend(DS3Aneg)
print(len(DS3A))
with open(path+"/DS/DS100/DS3A.json","w") as f:
  json.dump(DS3A,f)
###########
DS3B=[]
DS3Bneg=[]
with open(path+"/DATAfrom100itr/ITR-100/SetB.json","r") as f:
  EEX4=json.load(f)
for x in EEX4:
  if (x[2] == 1):
    DS3B.append(x)
  else:
    DS3Bneg.append(x)
DS3Bneg=random.sample(DS3Bneg, 3355)
DS3B.extend(DS3Bneg)
print(len(DS3B))
with open(path+"/DS/DS100/DS3B.json","w") as f:
  json.dump(DS3B,f)
# Out:
# 6710
# 6710
