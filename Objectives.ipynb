# %%
# <ignore> Calculate the result for A and B (average)
# Choose two existing state of the art method for PPI prediction (JUPPI, DING Et.al)
# Extract one dataset from itr 1 as DS1 (3355 positive, take 3355 negative from rem)
# Extract one dataset from itr 50 as DS2 (")
# Extract one daatset from itr 100 as DS3 (")

# 0, 9, 19

# Execute JUPPI and DING on DS1,2,3 
# Expectation: performance will be improved from DS1 to DS3
# Explore the mother paper for experiment.
